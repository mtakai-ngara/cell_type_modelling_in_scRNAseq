# %%
import pandas as pd
import celldiscoveryutilities as utils
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /anaconda/lib/python3.6/site-packages/numba/core/errors.py:144: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
#%%script false
#fname='/Users/mtanga/Documents/research/single_cell_modelling_and_analysis/notebooks_backup/python/results/scma/mESC/top_hvgs_comparison/quantile_0.0_1.0_preselected_quantile_none_scran_var_genes_removed/hs_scores.tab'
homo_scores_df=pd.read_pickle(path='../results/data/top_hvgs/top_hvgs.gz',compression='gzip')
split_groups =['modification_method', 'clustering_method', 'randomize_cells_labels',
               'top_var_genes_cut_off','top_var_genes_included','post_mod_genes','bin_end',
               'cells_count','protocol']
replicates_grps=['cells_count','modification_method', 'clustering_method','fc','genes_count', 
                 'randomize_cells_labels','method','top_var_genes_cut_off','top_var_genes_included',
                 'normalization_method', 'pca_components','bin_end','protocol','cells_count']
homo_scores_df=homo_scores_df[homo_scores_df.method!='direct']
replicates_grps=None
replicates_cut_off=5
out_dir='../results/top_hvgs_genes/figures'
fc_list=[0.2,0.3,3,5]   
#fc_list=None
#fc_order=[0.2,0.3,2,5]
fc_order=None
x_axis_subset=[5,10,30,50]
#x_axis_subset=None
in_col_wrap=2
hue='nTopGenes'
show_reps_counts=['fc','genes_count',hue]
show_reps_counts=None
hue_order=None
#Globala_variables
sns.set_context(context='paper',rc={'style':'white'})
#sns.set_palette(palette='colorblind')
#palette_dict='bright'
x_axis='genes_count'
fig_title='Top variable genes'
temp_palette=sns.color_palette(palette='Set1')
boxprops_dict=dict(linewidth=0)

# %%
if out_dir is not None:
    utils.safe_mkdir(out_dir)

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,
                                                         y_axis='adj_rand_index',in_kind='box',ci=95,
                                                         in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=fc_order,
                                                         show_reps_counts=show_reps_counts,subplot_title_size=10,
                                                         palette=temp_palette,facet_size=5,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,
                                                         boxplot_mean=True,boxplot_outliers=False,
                                                         boxprops=boxprops_dict,fig_title=fig_title)

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,
                                                         y_axis='hs',in_kind='box',ci=95,
                                                         in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=fc_order,
                                                         show_reps_counts=show_reps_counts,subplot_title_size=10,
                                                         palette=temp_palette,facet_size=5,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,
                                                         boxplot_mean=True,boxplot_outliers=False,
                                                         boxprops=boxprops_dict,fig_title=fig_title)

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,
                                                         y_axis='adj_mutual_info',in_kind='box',ci=95,
                                                         in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=fc_order,
                                                         show_reps_counts=show_reps_counts,subplot_title_size=10,
                                                         palette=temp_palette,facet_size=5,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,
                                                         boxplot_mean=True,boxplot_outliers=False,
                                                         boxprops=boxprops_dict,fig_title=fig_title)

# %%
homo_scores_df=homo_scores_df[homo_scores_df.method!='direct']
split_groups =['modification_method', 'clustering_method', 'randomize_cells_labels',
               'top_var_genes_cut_off','top_var_genes_included','post_mod_genes','bin_end',
               'cells_count','protocol']
replicates_grps=['cells_count','modification_method', 'clustering_method','fc','genes_count', 
                 'randomize_cells_labels','method','top_var_genes_cut_off','top_var_genes_included',
                 'normalization_method', 'pca_components','bin_end','protocol','cells_count']
replicates_cut_off=5
in_col_wrap=2
out_dir='../results/top_hvgs_genes/figures'
fc_list=[0.2,0.3,3,5]   
fc_order=None
x_axis_subset=[10,20,30,40,50]
show_reps_counts=['fc','genes_count',hue]
show_reps_counts=None

# %%
top_hvgs_cut_off=250
temp_hs_df=homo_scores_df[homo_scores_df.nTopGenes==top_hvgs_cut_off]
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_rand_index', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=250
temp_hs_df=homo_scores_df[homo_scores_df.nTopGenes==top_hvgs_cut_off]
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='hs', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=250
temp_hs_df=homo_scores_df[homo_scores_df.nTopGenes==top_hvgs_cut_off]
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_mutual_info', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=500
temp_hs_df=homo_scores_df[homo_scores_df.nTopGenes==top_hvgs_cut_off]
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_rand_index', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=500
temp_hs_df=homo_scores_df[homo_scores_df.nTopGenes==top_hvgs_cut_off]
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='hs', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=500
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_mutual_info', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=750
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_rand_index', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=750
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='hs', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=750
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_mutual_info', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=1000
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_rand_index', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=1000
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='hs', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
top_hvgs_cut_off=1000
fig_title=' '.join(['Top', str(top_hvgs_cut_off),'variable genes'])
figs=utils.plot_mean_cluster_score_heatmap(homo_scores_infile=temp_hs_df,score='adj_mutual_info', 
                                      output_dir=out_dir,x_axis_lab='fc', y_axis_lab='genes_count',col_order='fc',
                                      split_groups=split_groups,replicates_per_grp=replicates_cut_off,
                                      replicates_grps=replicates_grps,xlabs_ratotation=70, ylabs_ratotation=0,
                                      col_subset=None,in_cmap='seismic',add_column_dict=None,
                                      show_reps_counts=show_reps_counts,fig_title=fig_title)

# %%
hue='nTopGenes'
split_groups =['modification_method', 'clustering_method', 'randomize_cells_labels',
               'top_var_genes_cut_off','top_var_genes_included','post_mod_genes','bin_end',
               'cells_count','protocol',hue]
replicates_grps=['cells_count','modification_method', 'clustering_method','fc','genes_count', 
                 'randomize_cells_labels','method','top_var_genes_cut_off','top_var_genes_included',
                 'normalization_method', 'pca_components','bin_end','protocol','cells_count']
replicates_cut_off=5
out_dir=None
col_order=None
in_col_wrap=4
score='adj_rand_index'
fc_list=[0.2,0.3,3,5]  
temp_palette='Set1'
sns.set_style(style='white',rc={"xtick.major.size": 15, "ytick.major.size": 15})
g = sns.FacetGrid(data=homo_scores_df,hue=None,palette='coolwarm',col='nTopGenes',col_order=col_order,
                  col_wrap=in_col_wrap)
g = (g.map(sns.regplot, 'genes_count',score).add_legend())
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
    ax.tick_params(length=6, width=.5,bottom=True,left=True)
