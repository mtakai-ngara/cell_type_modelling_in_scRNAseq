# %%
import seaborn as sns
import pandas as pd
import celldiscoveryutilities as utils

# %matplotlib inline
# Out:
# /anaconda/lib/python3.6/site-packages/numba/core/errors.py:144: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
#%%script false
in_fname='../results/data/normalization_method/normalization_method_score.gz'
out_dir=None
homo_scores_df=pd.read_pickle(path=in_fname,compression='gzip')
#homo_scores_df=homo_scores_df[homo_scores_df.normalization_method=='rpkm'].reset_index(drop=True)
split_groups =['modification_method', 'clustering_method', 'randomize_cells_labels',
               'top_var_genes_cut_off','top_var_genes_included','post_mod_genes','pca_components',
               'bin_end','cells_count','protocol','bin_start','bin_end']
replicates_grps=['cells_count','modification_method', 'clustering_method','fc','genes_count', 
                 'randomize_cells_labels','method','top_var_genes_cut_off','top_var_genes_included',
                 'normalization_method', 'pca_components','bin_start','bin_end','protocol','cells_count']
replicates_grps=None
replicates_cut_off=5
out_dir=None
out_dir='../results/normalization_methods/figures'
fc_list=[0.2,0.3,3,5]   
x_axis_subset=[10,30,50,100]
#x_axis_subset=None
in_col_wrap=2
show_reps_counts=['fc','genes_count','normalization_method']
show_reps_counts=None
hue_order=None
#Globala_variables
sns.set_context(context='paper',rc={'style':'white'})
hue='normalization_method'
x_axis='genes_count'
temp_palette=sns.color_palette(palette='Set1',n_colors=len(homo_scores_df[hue].unique()))
boxprops_dict=dict(linewidth=0)

# %%
if out_dir is not None:
    utils.safe_mkdir(out_dir)

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,y_axis='adj_rand_index',
                                                         in_kind='box',ci=95,in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=None,
                                                         show_reps_counts=show_reps_counts,facet_size=4,
                                                         palette=temp_palette,subplot_title_size=10,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,boxplot_mean=True,
                                                         boxplot_outliers=False,boxprops=boxprops_dict,limit=100,
                                                        fig_title='Normalization method')

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,y_axis='hs',
                                                         in_kind='box',ci=95,in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=None,
                                                         show_reps_counts=show_reps_counts,facet_size=4,
                                                         palette=temp_palette,subplot_title_size=10,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,boxplot_mean=True,
                                                         boxplot_outliers=False,boxprops=boxprops_dict,limit=100,
                                                        fig_title='Normalization method')

# %%
fig=utils.plot_classification_scores_between_experiments(expriment_path=homo_scores_df, out_dir=out_dir,
                                                         x_axis=x_axis,split_groups=split_groups,
                                                         replicates_grps=replicates_grps,y_axis='adj_mutual_info',
                                                         in_kind='box',ci=95,in_col_wrap=in_col_wrap,
                                                         replicates_per_grp=replicates_cut_off,
                                                         col_subset=fc_list,hue=hue,hue_order=hue_order,
                                                         x_axis_subset=x_axis_subset,col_order_value=None,
                                                         show_reps_counts=show_reps_counts,facet_size=4,
                                                         palette=temp_palette,subplot_title_size=10,add_swarm=False,
                                                         swarm_points_size=5.0,x_axis_rotation=70,boxplot_mean=True,
                                                         boxplot_outliers=False,boxprops=boxprops_dict,limit=100,
                                                        fig_title='Normalization method')
